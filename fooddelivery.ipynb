# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
print("Pandas version:", pd.__version__)
# Out:
# Pandas version: 2.3.3

# %%
data = pd.read_excel(r"C:\Business Intelligence - Digital Skola\Tugas\Business Case & Decision-Making Strategy\study_case_food_delivery.xlsx")

# %%
data.columns
# Out:
# Index(['order_id', 'order_timestamp', 'customer_id', 'restaurant_id',
#        'courier_id', 'customer_lat', 'customer_lng', 'restaurant_lat',
#        'restaurant_lng', 'order_value', 'delivery_fee', 'estimated_prep_time',
#        'actual_prep_time', 'estimated_delivery_time', 'actual_delivery_time',
#        'total_delivery_duration', 'order_status', 'cancellation_reason',
#        'customer_rating', 'delivery_rating', 'weather_condition',
#        'time_of_day', 'distance_km', 'traffic_condition'],
#       dtype='object')
